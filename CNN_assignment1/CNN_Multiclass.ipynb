# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np

# %% [markdown]
# # Define a model

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),input_shape =(64,64,3),activation="relu"))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(16,(3,3),activation="relu"))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(8,(3,3),activation="relu"))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(4,(3,3),activation="relu"))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120,activation="relu"))
model.add(Dense(3, activation="softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy'])

# %% [markdown]
# # Load Data

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        r'/content/drive/My Drive/ineuron_DLCVNLP/ConvNeuralNetworks/CNN_assignment1/data',  # this is the target directory
        target_size=(64, 64),  # all images will be resized to 150x150
        batch_size=10)
# Out:
# Found 18 images belonging to 3 classes.

# %%
model.fit(train_generator,
          epochs=50,
          verbose=1,
          validation_data=train_generator)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 0s 83ms/step - loss: 1.0396 - accuracy: 0.5000 - val_loss: 1.0242 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0259 - accuracy: 0.5000 - val_loss: 1.0088 - val_accuracy: 0.5556
# Epoch 3/50
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0055 - accuracy: 0.5556 - val_loss: 0.9944 - val_accuracy: 0.6667
# Epoch 4/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9940 - accuracy: 0.6667 - val_loss: 0.9802 - val_accuracy: 0.7222
# Epoch 5/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.9774 - accuracy: 0.7222 - val_loss: 0.9586 - val_accuracy: 0.7778
# Epoch 6/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9571 - accuracy: 0.7778 - val_loss: 0.9347 - val_accuracy: 0.7222
# Epoch 7/50
# ...

# %%
model.save("conv.h5")

# %%
model.save_weights('conv_model_multiclass.h5')

# %%
img = load_img("/content/drive/My Drive/ineuron_DLCVNLP/ConvNeuralNetworks/CNN_assignment1/data/bumrah/1.jpeg",
               target_size=(64,64))

# %%
img = img_to_array(img)

# %%
img.shape
# Out:
# (64, 64, 3)

# %%
img = np.expand_dims(img, axis = 0)

# %%
img.shape
# Out:
# (1, 64, 64, 3)

# %%
preds = model.predict(img)

# %%
train_generator.class_indices
# Out:
# {'bumrah': 0, 'dhoni': 1, 'kohli': 2}

# %%
preds
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %%
preds[0][0]
# Out:
# 1.0

# %%
if preds[0][0] == 1:
  print("Bumrah")
elif preds[0][1] == 1:
  print("Dhoni")
else:
  print("Kohli")
# Out:
# Bumrah
