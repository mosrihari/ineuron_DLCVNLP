# %%
from bs4 import BeautifulSoup
import urllib.request
import json
from bs4 import BeautifulSoup
import re
import json
import pymongo
from urllib.request import urlopen
from urllib.request import Request

# %%
keyword = input("enter image to download:")
# Out:
# enter image to download:tree

# %%
BASE_URL = "http://www.google.com"

# %%
url = BASE_URL +"/search?q="+keyword.replace(" ","+")+"&source=lnms&tbm=isch"

# %%
url
# Out:
# 'http://www.google.com/search?q=tree&source=lnms&tbm=isch'

# %%
def get_soup(url,header):
    return BeautifulSoup(urlopen(Request(url,headers=header)),'html.parser')

# %%
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"
}

# %%
soup = get_soup(url,header)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("div",{"class":"rg_meta"})
# Out:
# []

# %% [markdown]
# ## New

# %%
from bs4 import BeautifulSoup
import requests
import re
from urllib.request import urlopen
from urllib.request import Request
import os
import argparse
import sys
import json

# adapted from http://stackoverflow.com/questions/20716842/python-download-images-from-google-image-search

def get_soup(url,header):
    return BeautifulSoup(urlopen(Request(url,headers=header)),'html.parser')

def main():
    query = "tree"
    max_images = 5
    image_type="Action"
    query= query.split()
    query='+'.join(query)
    url="https://www.google.co.in/search?q="+query+"&source=lnms&tbm=isch"
    header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
    soup = get_soup(url,header)
    ActualImages=[]# contains the link for Large original images, type of  image
    return soup

# %%
soup = main()

# %%
soup.find_all("img", alt=False)
# Out:
# [<img class="BcUvif" data-ils="2" data-src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRlJ1X6NrRcOp4rcQOA4qch5WYhRoyaEXqGfrNpZ8npGyxhaZ_r&amp;usqp=CAU" height="50" jsaction="rcuQ6b:trigger.M8vzZb;" width="50"/>,
#  <img class="BcUvif" data-ils="2" data-src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS4l6-DwnoirIMy4WdL2uY2hXQSe3g4crkaubg6A8_GfyPS4QWe&amp;usqp=CAU" height="50" jsaction="rcuQ6b:trigger.M8vzZb;" width="50"/>,
#  <img class="BcUvif" data-ils="2" data-src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTXdZrsKdGLu0zqRPwOeiEx6x9oeyAN_RaneoilNYk&amp;usqp=CAU" height="50" jsaction="rcuQ6b:trigger.M8vzZb;" width="50"/>,
#  <img class="BcUvif" data-ils="2" data-src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS164GKIOeJys4IXQMhzwVL2rMumxCr27eAiwKaViQ&amp;usqp=CAU" height="50" jsaction="rcuQ6b:trigger.M8vzZb;" width="50"/>,
# ...

# %%
import requests
base_url = "C:/Users/mohan/Documents/ineuron/WebScraping/ImageScraper/ImageDir/"
for e,img in enumerate(soup.find_all("img",alt=False)):
    img_url = img.attrs.get("data-src")
    with open(base_url+"tree{}".format(e)+".jpg", "wb") as f:
        f.write(requests.get(img_url).content)

# %%
img_url
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRlJ1X6NrRcOp4rcQOA4qch5WYhRoyaEXqGfrNpZ8npGyxhaZ_r&usqp=CAU'

# %%
url = "http://www.google.com"

# %%
from urllib.parse import urljoin, urlparse

# %%
img_url = urljoin(url, img_url)

# %%
img_url
# Out:
# '...'

# %% [markdown]
# Claim:
# With reference to the below link, it is not possible to extract google images completely as it is restricted in the recent times
# we can only get tile images from google and we cannot get full images
# #https://stackoverflow.com/questions/36438261/extracting-images-from-google-images-using-src-and-beautifulsoup

# %% [markdown]
# # Bing images

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download()

# %%
downloader.download("tree",limit=10,output_dir="ImageDir")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Joshua_Tree_01.jpg/1200px-Joshua_Tree_01.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Joshua_Tree_01.jpg/1200px-Joshua_Tree_01.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Joshua_Tree_01.jpg/1200px-Joshua_Tree_01.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/0/0f/Melaleuca_leucadendra-large2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Ericaceae_-_Arbutus_andrachne.JPG/1200px-Ericaceae_-_Arbutus_andrachne.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Tree_kangaroo2.jpg/1200px-Tree_kangaroo2.jpg
# ...

# %%
from bson import Binary

# %%
pwd
# Out:
# 'C:\\Users\\mohan\\Documents\\ineuron\\WebScraping\\ImageScraper'

# %%
# !cd ImageDir

# %%
pwd
# Out:
# 'C:\\Users\\mohan\\Documents\\ineuron\\WebScraping\\ImageScraper'

# %%
from PIL import Image
import io
img = Image.open('ImageDir/tree/Image_1.jpg')

imgByteArr = io.BytesIO()
img.save(imgByteArr, format='jpeg')
imgByteArr = imgByteArr.getvalue()

# %%
imgByteArr
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x06@\x04\xb0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd3\x
# ...

# %%
import PIL.Image as Image

# %%
image = Image.open(io.BytesIO(imgByteArr))
image.save("myimage.jpg")
